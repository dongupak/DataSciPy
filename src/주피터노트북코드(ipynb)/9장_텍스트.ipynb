# %% [markdown]
# # 생능출판사 "따라하며 배우는 파이썬과 데이터과학" 코드 9장
# ## chapter 9
# ### 텍스트를 처리해보자

# %% [markdown]
# ### 9.2 기본적인 텍스트 처리

# %% [markdown]
# #### 문자열을 문자로 분해해보자

# %%
s = 'Monty Python'
s[0]            # 인덱싱
# Out:
# 'M'

# %%
t = s[6:10]     # 슬라이싱
t
# Out:
# 'Pyth'

# %%
my_string = "Hello"
characters = list(my_string)    # 문자열을 리스트로 변환시킴
print(characters)               # ['H', 'e', 'l', 'l', 'o']
# Out:
# ['H', 'e', 'l', 'l', 'o']

# %% [markdown]
# #### split() 메소드로 문자열을 단어로 나누어보자

# %%
s = 'Welcome to Python' 
s.split()
# Out:
# ['Welcome', 'to', 'Python']

# %%
s = '2024.8.15' 
s.split('.')        # 분리문자를 명시하여 분리함
# Out:
# ['2024', '8', '15']

# %% [markdown]
# #### join() 메소드로 단어들을 붙여서 문자열을 만들어보자

# %%
','.join(['apple', 'grape', 'banana'])
# Out:
# 'apple,grape,banana'

# %%
'-'.join('010.1234.5678'.split('.'))  # .으로 구분된 전화번호를 하이픈(-)으로 고치기
# Out:
# '010-1234-5678'

# %% [markdown]
# #### 부분 문자열의 출현 횟수 계산

# %%
s = 'www.booksr.co.kr'      # 생능출판사의 홈페이지
s.count('.')                # . 이 몇 번 나타나는가를 알려준다
# Out:
# 3

# %% [markdown]
# #### startswith()와 endswith()

# %%
s = "Hello, World!"
s.startswith("Hello")       # s 문자열이 "Hello"로 시작하는가
# Out:
# True

# %% [markdown]
# ### 9.3 텍스트를 변경하고 포매팅하는 방법

# %%
s = 'Hello, World!'
s.lower()       # s 문자열을 소문자로 변환
# Out:
# 'hello, world!'

# %%
s.upper()        # s 문자열을 대문자로 변환
# Out:
# 'HELLO, WORLD!'

# %%
s = "Hello, World!"
s.replace("World", "Python")
# Out:
# 'Hello, Python!'

# %%
s = 'Hello, World!' 
s.replace('!', '')
# Out:
# 'Hello, World'

# %% [markdown]
# #### 공백 삭제

# %%
s = '       Hello, World!       '
s.strip()       # 왼쪽과 오른쪽의 공백 문자를 모두 제거한다
# Out:
# 'Hello, World!'

# %%
s.lstrip()      # 왼쪽의 공백 문자만 제거한다
# Out:
# 'Hello, World!       '

# %%
s.rstrip()      # 오른쪽의 공백 문자만 제거한다
# Out:
# '       Hello, World!'

# %%
s = '########this is an example#####'
s.strip('#')    # 문자열의 앞 뒤에 있는 해시 문자를 제거한다
# Out:
# 'this is an example'

# %%
s = '########this is an example#####'
s.lstrip('#')
# Out:
# 'this is an example#####'

# %%
s.rstrip('#')
# Out:
# '########this is an example'

# %% [markdown]
# #### 부분 문자열 찾기, 그리고 다양한 포매팅

# %%
s = 'www.booksr.co.kr'
s.find('.kr')
# Out:
# 13

# %%
s.find('x')     # 'x' 문자열이 없을 경우 -1을 반환함
# Out:
# -1

# %%
s = 'www.booksr.co.kr'
n = s.index('b')
print('s의 b 인덱스 =', n)      # 'b' 문자열이 없을 경우 -1을 반환함
# Out:
# s의 b 인덱스 = 4

# %%
s = 'www.booksr.co.kr'
n = s.index('b')
print(f's의 b 인덱스 = {n}')      # {n} 위치에 n의 실제값이 출력됨
# Out:
# s의 b 인덱스 = 4

# %%
s1 = 'print \n in my string'    # r-string을 사용 안함
print(s1)                       # \n 위치에 줄바꿈이 발생
# Out:
# print
#  in my string

# %%
s2 = r'print \n in my string'   # r-string을 사용 함
print(s2)                       # \n 이 그대로 나타남
# Out:
# print \n in my string

# %% [markdown]
# ### LAB 9-1 글자 수, 단어 수, 평균 단어 길이

# %%
s="This movie was terrible! The acting was poor and the story was boring."

print(f"s={s}")
print(f"\n글자수={len(s)}")
words = s.split()
print(f"단어들의 리스트={words}")
print(f"단어 수={len(words)}")
print(f"평균 단어 길이={sum(len(word) for word in words)/len(words)}")
# Out:
# s=This movie was terrible! The acting was poor and the story was boring.
#
# 글자수=70
# 단어들의 리스트=['This', 'movie', 'was', 'terrible!', 'The', 'acting', 'was', 'poor', 'and', 'the', 'story', 'was', 'boring.']
# 단어 수=13
# 평균 단어 길이=4.461538461538462

# %% [markdown]
# ### LAB 9-2 불용어 제거하기

# %%
stop_words = ['is', 'and', 'the', 'a', 'an', 'in', 'of', 'to']

text = "This is an example of removing stop words from a string."
words = text.split()
filtered_sentence = [word for word in words if word.lower() not in stop_words]
print(f"입력={text}")
print(f'출력={" ".join(filtered_sentence)}')
# Out:
# 입력=This is an example of removing stop words from a string.
# 출력=This example removing stop words from string.

# %% [markdown]
# ### 9.4 불용어를 쉽게 처리하자

# %%
pip install nltk

# %%
import nltk
from nltk.corpus import stopwords       # 불용어 패키지를 사용하기 위해 가져온다 
nltk.download('stopwords')              # nltk 패키지로부터 불용어를 다운받는다 
nltk.download('punkt')                  # nltk 패키지로부터 토큰화 작업을 위하여 punkt를 다운받는다 
text = "This is an example of removing stop words from a string."
stop_words = set(stopwords.words("english"))
words = nltk.word_tokenize(text)

filtered_sentence = [w for w in words if not w in stop_words] 
print(f"입력={text}")
print(f'출력={" ".join(filtered_sentence)}')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jeongsejin/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/jeongsejin/nltk_data...
# 입력=This is an example of removing stop words from a string.
# 출력=This example removing stop words string .
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# ### LAB 9-3 트위터 메시지 처리

# %%
s = "It's Not The Right Time To Conduct Exams. MY DEMAND IN BOLD AND CAPITAL. NO EXAMS IN COVID!!!"

print(f"입력={s}") 
count = 0
for word in s.split():
    if( word == word.upper() ):     # 대문자로 변환한 것과 동일하면 대문자 단어 
        count += 1
print(f"\n대문자 단어의 수={count}") 
t = s.lower()
t = t.replace('!',"");
t = t.replace('.',"");
t = t.replace("'",""); 
print(f"결과={t}")
# Out:
# 입력=It's Not The Right Time To Conduct Exams. MY DEMAND IN BOLD AND CAPITAL. NO EXAMS IN COVID!!!
#
# 대문자 단어의 수=10
# 결과=its not the right time to conduct exams my demand in bold and capital no exams in covid

# %% [markdown]
# ### LAB 9-4 단어 빈도 계산

# %%
# (1) 딕셔너리를 이용하는 방법

s='the quick brown fox jumps over the lazy dog.' 
print(f"입력={s}")

counter = {}
words = s.split() 
for word in words:
    if word in counter: 
        counter[word] += 1
    else:
        counter[word] = 1
print(f"출력={counter}")
# Out:
# 입력=the quick brown fox jumps over the lazy dog.
# 출력={'the': 2, 'quick': 1, 'brown': 1, 'fox': 1, 'jumps': 1, 'over': 1, 'lazy': 1, 'dog.': 1}

# %%
# (2) Counter 클래스를 이용하는 방법

from collections import Counter

s='the quick brown fox jumps over the lazy dog.' 
print(f"입력={s}")
words = s.split()

frequency = Counter(words) 
print(f"출력={frequency}")
# Out:
# 입력=the quick brown fox jumps over the lazy dog.
# 출력=Counter({'the': 2, 'quick': 1, 'brown': 1, 'fox': 1, 'jumps': 1, 'over': 1, 'lazy': 1, 'dog.': 1})

# %% [markdown]
# ### LAB 9-5 영화평 분석

# %%
pip install textblob

# %%
from textblob import TextBlob
review = "This movie was terrible! The acting was poor and the story was boring."
sentiment = TextBlob(review).sentiment.polarity
print(f"입력={review}\n")

if sentiment > 0: 
    print("결과=긍정적")
elif sentiment == 0: 
    print("결과=중립")
else: 
    print("결과=부정적")
# Out:
# 입력=This movie was terrible! The acting was poor and the story was boring.
#
# 결과=부정적

# %% [markdown]
# ### 9.5 워드 클라우드

# %%
pip install wordcloud

# %%
from wordcloud import WordCloud 
wordcloud = WordCloud()

# %%
text = "Hello Hello Hello This is a word cloud example." 
wordcloud.generate(text)

# %%
import matplotlib.pyplot as plt 
plt.imshow(wordcloud, interpolation='bilinear') 
plt.axis("off")
plt.show()

# %% [markdown]
# #### 워드 클라우드의 여러 가지 인자

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# 텍스트 파일 읽기
with open('test.txt', 'r', encoding='utf-8') as f:
    text = f.read()
# 워드 클라우드 생성
wordcloud = WordCloud(font_path='malgun.ttf',           # 폰트
                      background_color='white',         # 배경색
                      width=800,                        # 폭
                      height=800,                       # 높이
                      max_words=100,                    # 최대 단어 개수
                      max_font_size=200,                # 최대 폰트 크기
                      contour_width=1,                  # 윤곽선 두께
                      contour_color='steelblue',        # 윤곽선 색상
                      collocations=False).generate(text)
# 워드 클라우드 그리기
plt.figure(figsize=(8,8))                           # 이미지 크기 
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[46], line 4
#       2 import matplotlib.pyplot as plt
#       3 # 텍스트 파일 읽기
# ----> 4 with open('test.txt', 'r', encoding='utf-8') as f:
#       5     text = f.read()
#       6 # 워드 클라우드 생성
#
# File ~/Library/Python/3.11/lib/python/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.txt'

# %% [markdown]
# ### 9.6 한글 워드클라우드와 이미지 형태로 만들기

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(font_path = 'malgun.ttf')     # 한글 폰트를 지정

text = '''한글 클라우드를 만들기 위해서는
텍스트 데이터가 필요합니다. 텍스트 데이터는 txt, csv, 엑셀 파일 등 다양한 형식으로 제공될 수 있습니다.
이 예제에서는 txt 파일을 불러오겠습니다.''' 
wordcloud.generate(text)

import matplotlib.pyplot as plt 
plt.imshow(wordcloud, interpolation='bilinear') 
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[47], line 8
#       3 wordcloud = WordCloud(font_path = 'malgun.ttf')     # 한글 폰트를 지정
#       5 text = '''한글 클라우드를 만들기 위해서는
#       6 텍스트 데이터가 필요합니다. 텍스트 데이터는 txt, csv, 엑셀 파일 등 다양한 형식으로 제공될 수 있습니다.
#       7 이 예제에서는 txt 파일을 불러오겠습니다.'''
# ----> 8 wordcloud.generate(text)
#      10 import matplotlib.pyplot as plt
#      11 plt.imshow(wordcloud, interpolation='bilinear')
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/wordcloud/wordcloud.py:642, in WordCloud.generate(self, text)
#     627 def generate(self, text):
#     628     """Generate wordcloud from text.
#     629
#     630     The input "text" is expected to be a natural text. If you pass a sorted
#    (...)
#     640     self
#     641     """
# --> 642     return self.generate_from_text(text)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/wordcloud/wordcloud.py:624, in WordCloud.generate_from_text(self, text)
#     607 """Generate wordcloud from text.
#     608
#     609 The input "text" is expected to be a natural text. If you pass a sorted
#    (...)
#     621 self
#     622 """
#     623 words = self.process_text(text)
# --> 624 self.generate_from_frequencies(words)
#     625 return self
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/wordcloud/wordcloud.py:453, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     451     font_size = self.height
#     452 else:
# --> 453     self.generate_from_frequencies(dict(frequencies[:2]),
#     454                                    max_font_size=self.height)
#     455     # find font sizes
#     456     sizes = [x[1] for x in self.layout_]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/wordcloud/wordcloud.py:506, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     504     break
#     505 # try to find a position
# --> 506 font = ImageFont.truetype(self.font_path, font_size)
#     507 # transpose font optionally
#     508 transposed_font = ImageFont.TransposedFont(
#     509     font, orientation=orientation)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/PIL/ImageFont.py:819, in truetype(font, size, index, encoding, layout_engine)
#     816     return FreeTypeFont(font, size, index, encoding, layout_engine)
#     818 try:
# --> 819     return freetype(font)
#     820 except OSError:
#     821     if not is_path(font):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/PIL/ImageFont.py:816, in truetype.<locals>.freetype(font)
#     815 def freetype(font):
# --> 816     return FreeTypeFont(font, size, index, encoding, layout_engine)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/PIL/ImageFont.py:245, in FreeTypeFont.__init__(self, font, size, index, encoding, layout_engine)
#     243                 load_from_bytes(f)
#     244             return
# --> 245     self.font = core.getfont(
#     246         font, size, index, encoding, layout_engine=layout_engine
#     247     )
#     248 else:
#     249     load_from_bytes(font)
#
# OSError: cannot open resource

# %%
from wordcloud import WordCloud
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt             # matplotlib은 추후에 설명합니다. 
# 워드 클라우드를 그릴 텍스트 데이터
text = '''Love is a river that flows so free, 
A beautiful sight for all to see.
It glides around every bend,
A source of life that never ends.'''
mask = np.array(Image.open("comment.png"))  # 사용할 이미지 파일 
# 워드 클라우드 생성을 위한 다양한 키워드 인자들 설정
wc = WordCloud(background_color="white", mask=mask,
               contour_width=3, contour_color='steelblue') 
wc.generate(text)                           # 텍스트를 이용해 워드 클라우드 생성
wc.to_file("result.png")                    # 워드 클라우드 이미지 저장
# 워드 클라우드 이미지 출력
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")                             # matplotlib에서 축 설명을 생략함-추후 설명 예정 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[48], line 10
#       5 # 워드 클라우드를 그릴 텍스트 데이터
#       6 text = '''Love is a river that flows so free,
#       7 A beautiful sight for all to see.
#       8 It glides around every bend,
#       9 A source of life that never ends.'''
# ---> 10 mask = np.array(Image.open("comment.png"))  # 사용할 이미지 파일
#      11 # 워드 클라우드 생성을 위한 다양한 키워드 인자들 설정
#      12 wc = WordCloud(background_color="white", mask=mask,
#      13                contour_width=3, contour_color='steelblue')
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/PIL/Image.py:3247, in open(fp, mode, formats)
#    3244     filename = fp
#    3246 if filename:
# -> 3247     fp = builtins.open(filename, "rb")
#    3248     exclusive_fp = True
#    3250 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'comment.png'

# %% [markdown]
# #### [고급 심화] konlpy 모듈과 Okt 형태소 분석기

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(font_path = 'malgun.ttf')

text = '''한글 클라우드를 만들기 위해서는
텍스트 데이터가 필요합니다. 텍스트 데이터는 txt, csv, 엑셀 파일 
등 다양한 형식으로 제공될 수 있습니다.
이 예제에서는 txt 파일을 불러오겠습니다.'''

from konlpy.tag import Okt 
okt = Okt()
text = okt.nouns(text)

stopwords = ['의', '가', '이', '은', '들', '는', '좀', '잘', '걍', '과', '도', '를', '으로', '자', ' 에', '와', '한', '하다']
clean_text = [word for word in text if not word in stopwords]
from collections import Counter
c = Counter(clean_text) 
wordcloud.generate_from_frequencies(c)

import matplotlib.pyplot as plt 
plt.imshow(wordcloud, interpolation='bilinear') 
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[49], line 18
#      16 from collections import Counter
#      17 c = Counter(clean_text)
# ---> 18 wordcloud.generate_from_frequencies(c)
#      20 import matplotlib.pyplot as plt
#      21 plt.imshow(wordcloud, interpolation='bilinear')
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/wordcloud/wordcloud.py:453, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     451     font_size = self.height
#     452 else:
# --> 453     self.generate_from_frequencies(dict(frequencies[:2]),
#     454                                    max_font_size=self.height)
#     455     # find font sizes
#     456     sizes = [x[1] for x in self.layout_]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/wordcloud/wordcloud.py:506, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     504     break
#     505 # try to find a position
# --> 506 font = ImageFont.truetype(self.font_path, font_size)
#     507 # transpose font optionally
#     508 transposed_font = ImageFont.TransposedFont(
#     509     font, orientation=orientation)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/PIL/ImageFont.py:819, in truetype(font, size, index, encoding, layout_engine)
#     816     return FreeTypeFont(font, size, index, encoding, layout_engine)
#     818 try:
# --> 819     return freetype(font)
#     820 except OSError:
#     821     if not is_path(font):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/PIL/ImageFont.py:816, in truetype.<locals>.freetype(font)
#     815 def freetype(font):
# --> 816     return FreeTypeFont(font, size, index, encoding, layout_engine)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/PIL/ImageFont.py:245, in FreeTypeFont.__init__(self, font, size, index, encoding, layout_engine)
#     243                 load_from_bytes(f)
#     244             return
# --> 245     self.font = core.getfont(
#     246         font, size, index, encoding, layout_engine=layout_engine
#     247     )
#     248 else:
#     249     load_from_bytes(font)
#
# OSError: cannot open resource

# %% [markdown]
# ### LAB 9-6 위키피디아 워드 클라우드

# %%
import wikipedia
# 위키백과 사전의 컨텐츠 제목을 명시해 준다
wiki = wikipedia.page('Artificial intelligence') 
# 이 페이지의 텍스트 컨텐츠를 추출하도록 한다
text = wiki.content

# %%
from wordcloud import WordCloud
wordcloud = WordCloud(width = 2000, height = 1500).generate(text) 
import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
import wikipedia
# 위키백과 사전의 컨텐츠 제목을 명시해 준다
wiki = wikipedia.page('Artificial intelligence') 
# 이 페이지의 텍스트 컨텐츠를 추출하도록 한다
text = wiki.content

from wordcloud import WordCloud, STOPWORDS
# 불용어가 제외된 워드 클라우드를 만들자
s_words = STOPWORDS.union( {'one', 'using', 'first', 'two', 'make', 'use'} ) 
wordcloud = WordCloud(width = 2000, height = 1500,
                      stopwords = s_words).generate(text)

import matplotlib.pyplot as plt 
plt.imshow(wordcloud, interpolation='bilinear') 
plt.axis("off")
plt.show()

# %% [markdown]
# ### 9.7 정규식을 알아보자

# %%
import re               # 이 코드 이후의 모든 정규식 코드 예제에서는 import re 문을 사용합니다 
text = "이번 학기 개설 과목은 CS101입니다."
match = re.search('[A-Za-z]{2}\d{3}', text)
if match:
    print("과목 코드가 발견됨:", match) 
else:
    print("과목 코드가 발견되지 않음:", match)
# Out:
# 과목 코드가 발견됨: <re.Match object; span=(13, 18), match='CS101'>

# %% [markdown]
# #### 메타 문자

# %%
re.search('A..A', 'ABBA')   # 조건에 맞음
# Out:
# <re.Match object; span=(0, 4), match='ABBA'>

# %%
re.search('A..A', 'ABBBA')  # 조건에 맞지 않음

# %%
re.search('AB*', 'A')       # 'A'라는 문자열이 조건에 맞음
# Out:
# <re.Match object; span=(0, 1), match='A'>

# %%
re.search('AB*', 'ABB')     # 'ABB'라는 문자열이 조건에 맞음
# Out:
# <re.Match object; span=(0, 3), match='ABB'>

# %%
re.search('AB+', 'A')       # 조건에 맞지 않음
re.search('AB+', 'AB')
# Out:
# <re.Match object; span=(0, 2), match='AB'>

# %%
txt3 = 'My life my life my life in the sunshine'
re.findall('[Mm]y', txt3)
# Out:
# ['My', 'my', 'my']

# %% [markdown]
# ### 9.8 정규식을 이용하여 특정한 패턴 찾기

# %% [markdown]
# #### 문자열에서 전화번호를 찾는 예제

# %%
# 문자열에서 전화번호를 찾는 예제
string = "My phone number is 010-1234-5678. Call me anytime." 
result = re.search('\d{3}-\d{4}-\d{4}', string) 
print(result.group())   # 010-1234-5678
# Out:
# 010-1234-5678

# %% [markdown]
# #### 문자열에서 숫자를 찾는 예제

# %%
text = 'There are 12 apples and 3 oranges' 
numbers = re.findall('\d+', text) 
print(numbers)
# Out:
# ['12', '3']

# %% [markdown]
# #### 이메일 주소에서 도메인 추출하기

# %%
email = 'user@example.com'
domain = re.search('@\w+\.\w+', email) 
print(domain.group())
# Out:
# @example.com

# %% [markdown]
# #### 주민등록번호 검사하기

# %%
def is_valid_jumin(st):
    pattern = '^\d{6}\-\d{7}'         # 출생년도-7자리 숫자로 주민등록번호를 검사하는 정규식 
    match = re.match(pattern, st)
    return match

jumin = input('당신의 주민등록번호는: ')    # 주민등록번호를 입력받는 코드 
if is_valid_jumin(jumin):
    print('주민등록번호가 유효합니다.') 
else:
    print('주민등록번호가 유효하지 않습니다.')
# Out:
# 주민등록번호가 유효합니다.

# %% [markdown]
# ### 9.9 정규식을 이용하여 패턴 대체하기

# %%
text = 'abc123def456'
result = re.sub('\d', '', text) # text 문자열에서 숫자를 모두 제거함 
print(result)                   # 'abcdef'
# Out:
# abcdef

# %%
text = 'My email is john@example.com' 
result = re.sub('\w+@\w+\.\w+', '****', text) 
print(result)       # 'My email is ****'
# Out:
# My email is ****

# %%
text = '03/17/2024'
new_text = re.sub('(\d{2})/(\d{2})/(\d{4})', r'\3-\1-\2', text) 
print(new_text)     # 2024-03-17
# Out:
# 2024-03-17

# %% [markdown]
# ### LAB 9-7 HTML 태그를 제거하자

# %%
import re

html = input("HTML 문장을 입력하세요: ")
# HTML 태그를 제거하는 sub()함수와 정규표현식
result = re.sub('<[^>]+>', '', html) 
print(result)
# Out:
# Hello, world!This is an example.
