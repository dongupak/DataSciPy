# %% [markdown]
# # 생능출판사 "따라하며 배우는 파이썬과 데이터과학" 코드 6장
# ## chapter 6
# ### 함수로 일처리를 짜임새있게 하자

# %% [markdown]
# #### def 예약어를 이용하여 함수를 작성하고 호출하기

# %%
def print_address():
    print('경상북도 울릉군 울릉읍')
    print('독도이사부길 63')

print_address()  # 정의한 함수를 호출
# Out:
# 경상북도 울릉군 울릉읍
# 독도이사부길 63

# %% [markdown]
# ### 6.2 함수를 만들고 불러서 일을 시켜보자

# %%
print('경상북도 울릉군 울릉읍')
print('독도이사부길 63')
# Out:
# 경상북도 울릉군 울릉읍
# 독도이사부길 63

# %%
print_address()
print_address()
print_address()
# Out:
# 경상북도 울릉군 울릉읍
# 독도이사부길 63
# 경상북도 울릉군 울릉읍
# 독도이사부길 63
# 경상북도 울릉군 울릉읍
# 독도이사부길 63

# %% [markdown]
# #### 함수에 값을 넘겨주고 일을 시키자

# %%
def print_address(name):
    print("서울 특별시 종로구 1번지")
    print("파이썬 빌딩 7층")
    print("수신 :", name)

print_address("홍길동")     # "홍길동" 대신 다른 이름을 넣을 수 있다
print_address("널널한 교수")
# Out:
# 서울 특별시 종로구 1번지
# 파이썬 빌딩 7층
# 수신 : 홍길동
# 서울 특별시 종로구 1번지
# 파이썬 빌딩 7층
# 수신 : 널널한 교수

# %% [markdown]
# ### 6.3 함수에 일을 시키고 그 값을 받아오도록 하자

# %%
def calculate_area(radius):
    area = 3.14 * radius**2     # 원의 면적을 구하는 근사식
    return area                 # 이전 줄에서 구한 area 값을 호출문에 돌려준다

# %%
c_area = calculate_area(5.0)   # calculate_are() 함수가 계산한 값을 c_area에 저장

# %%
print(calculate_area (5.0))
# Out:
# 78.5

# %%
area_sum = calculate_area(5.0) + calculate_area(10.0)
print(area_sum)
# Out:
# 392.5

# %%
calculate_area(10.0)   # 함수를 호출만 하고 그 반환값을 사용안함
# Out:
# 314.0

# %% [markdown]
# #### 함수에 여러 개의 값을 넘겨주는 고급 기능

# %%
def get_sum(start, end):            # start, end를 매개변수로하여 인자를 받는다
    s = 0
    for i in range(start, end+1):   # start부터 end까지 정수의 합을 구함
        s += i
    return s                        # start부터 end까지 수의 합을 반환한다

x = get_sum(1,10)                   # 인자 1, 10을 넘겨주며 함수 get_sum()을 호출함
print('1에서 10까지의 합 :', x)        # 1에서 100까지 정수의 합 55를 출력한다
# Out:
# 1에서 10까지의 합 : 55

# %%
y = get_sum(1,20)                   # 1과 20이 인자가 된다. y는 1에서 20까지의 합을 반환받는다.
print('1에서 20까지의 합 :', y)
# Out:
# 1에서 20까지의 합 : 210

# %% [markdown]
# ### 6.4 여러 개의 값을 넘겨주고 여러 개의 값을 돌려받자

# %%
def sort_num(n1, n2):       # 2개의 값을 받아오는 함수
    if n1 < n2:
        return n1, n2       # n1이 더 작으면 n1, n2 순서로 반환
    else:
        return n2, n1       # n2가 더 작으면 n2, n1 순서로 반환

print(sort_num(110, 210))   # 110과 210을 함수의 인자로 전달하고 반환되는 값을 출력
print(sort_num(2100, 80))
# Out:
# (110, 210)
# (80, 2100)

# %%
def calc(n1, n2):
    return n1 + n2, n1 - n2, n1 * n2, n1 / n2  # 덧셈, 뺄셈, 곱셈, 나눗셈 결과를 반환

n1, n2 = 200, 100
t1, t2, t3, t4 = calc(n1, n2)  # 네 개의 값을 반환받기 위해 4개의 변수를 사용함
print(n1, '+', n2, '=', t1)
print(n1, '-', n2, '=', t2)
print(n1, '*', n2, '=', t3)
print(n1, '/', n2, '=', t4)
# Out:
# 200 + 100 = 300
# 200 - 100 = 100
# 200 * 100 = 20000
# 200 / 100 = 2.0

# %% [markdown]
# ### LAB 6-1 사각형을 그리는 함수 작성하기

# %%
import turtle 

t = turtle.Turtle() 
t.shape("turtle") 

def square(length):       # length는 한변의 길이 
    for i in range(4): 
        t.forward(length) 
        t.left(90) 
 
square(100)      # square() 함수를 호출한다. 
square(200)      # 호출시 인자값을 100, 200, 300으로 다르게 한다
square(300) 
turtle.done()
# Out:
# 2024-02-14 18:16:39.489 Python[76071:1018848] WARNING: Secure coding is not enabled for restorable state! Enable secure coding by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState: and returning YES.

# %% [markdown]
# ### 6.5 변수의 범위는 어디까지인가

# %%
def print_counter():
    print('counter =', counter)  # 함수 내부의 counter 값

counter = 100
print_counter()
print('counter =', counter)      # 함수 외부의 counter 값
# Out:
# counter = 100
# counter = 100

# %%
def print_counter():
    counter = 200
    print('counter =', counter)  # 함수 내부의 counter 값

counter = 100
print_counter()
print('counter =', counter)      # 함수 외부의 counter 값
# Out:
# counter = 200
# counter = 100

# %% [markdown]
# #### 함수 안에서 전역변수 사용하기 : global 키워드

# %%
def print_counter():
    global counter               # 함수 외부의 전역변수 counter를 사용하겠다는 선언
    counter = 200
    print('counter =', counter)  # 함수 내부의 counter 값

counter = 100
print_counter()
print('counter =', counter)      # 함수 외부의 counter 값
# Out:
# counter = 200
# counter = 200

# %%
def calculate_area(radius): 
    global area                 # 전역변수 area를 사용함
    area = 3.14 * radius**2 
    return                      # 반환하는 값이 없음
 
area = 0 
r = float(input("원의 반지름을 입력하세요 : ")) 
calculate_area(r) 
print(area)
# Out:
# 78.5

# %% [markdown]
# ### 6.6 함수에 쉽게 일을 시키는 디폴트 인자

# %%
def order(num, pickle, onion):
    print('햄버거 {0} 개 - 피클 {1}, 양파 {2}'.format(num, pickle, onion))

order(1, False, True)
# Out:
# 햄버거 1 개 - 피클 False, 양파 True

# %%
order(1)    # 인자를 1개만 전달하여 order()을 호출함
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 order(1)    # 인자를 1개만 전달하여 order()을 호출함
#
# TypeError: order() missing 2 required positional arguments: 'pickle' and 'onion'

# %%
def order(num, pickle = True, onion = True):
    print('햄버거 {0} 개 - 피클 {1}, 양파 {2}'.format(num, pickle, onion))

order(1, pickle = False, onion = True)
order(2)  # 햄버거 2개를 주문, 디폴트로 pickle, onion 값은 True임
# Out:
# 햄버거 1 개 - 피클 False, 양파 True
# 햄버거 2 개 - 피클 True, 양파 True

# %%
order(3, onion = False, pickle = True) # 인자의 순서를 바꾸었다.
# Out:
# 햄버거 3 개 - 피클 True, 양파 False

# %% [markdown]
# #### 키워드 인자로 더욱더 고급지게 함수 활용하기

# %%
def power(base, exponent): 
    return base**exponent   # base가 밑이고, exponent가 지수값이다.

# %%
 power(2, 10)  # 2의 10승을 반환한다
# Out:
# 1024

# %%
power(10, 2)  # 10의 2승을 반환한다
# Out:
# 100

# %%
power(base=2, exponent=10)  # 2의 10승을 반환한다
# Out:
# 1024

# %%
power(exponent=10, base=2)  # 2의 10승을 반환한다
# Out:
# 1024

# %% [markdown]
# ### LAB 6-2 주급 계산 프로그램

# %%
def weeklyPay(rate, hour):
    if (hour > 30):
        money = rate*30 + 1.5*rate*(hour-30)
    else:
        money = rate*hour
    return money

r = int(input("시급을 입력하시오: "))          # 시급입력받기
h = int(input("근무 시간을 입력하시오: "))      # 근무시간 입력받기
print("주급은 " + str(weeklyPay(rate = r, hour = h))) # 키워드 인자 사용
# Out:
# 주급은 420000.0

# %% [markdown]
# ### LAB 6-3 n-각형을 그리는 함수 만들어보기

# %%
import turtle
t = turtle.Turtle()

# n-각형을 그리는 함수를 정의한다.
def n_polygon(n, length):
    for i in range(n):
        t.forward(length)
        t.left(360//n)  # 정수 나눗셈은 //으로 한다.

for i in range(10):
    t.left(20)
    n_polygon(6, 100)

# %% [markdown]
# ### LAB 6-4 리스트에서 최대/최소값을 찾는 함수

# %%
def getMinMax(mylist, method):
   min_Value = mylist[0]     # 리스트의 첫 번째 값을 min_value로 두자
   max_Value = mylist[0]     # 리스트의 첫 번째 값을 max_value로 두자

   if method == 'max' :
       for value in mylist:
           if value > max_Value:
               max_Value = value
       return max_Value
   elif method == 'min' :
       for value in mylist:
           if value < min_Value:
               min_Value = value
       return min_Value
   else :
       return 'Error : 잘못된 명령입니다.'

list_data = [82, 27, 90, 30, 87, 56] # 데이터를 여러 개 담는 리스트 자료구조
print(list_data)
s = input('최대값을 원하면 max, 최소값을 원하면 min을 입력하시오: ')
print(getMinMax(mylist = list_data, method = s))
# Out:
# [82, 27, 90, 30, 87, 56]
# 90

# %% [markdown]
# ### LAB 6-5 리스트에서 최대/최소값을 찾아서 두 개를 반환하는 함수

# %%
def getMinAndMax(mylist):
    min_value = mylist[0]           # 리스트의 첫 번째 값을 min_value로 두자
    max_value = mylist[0]           # 리스트의 첫 번째 값을 max_value로 두자

    for value in mylist:
        if value > max_value: 
            max_value = value 
        if value < min_value: 
            min_value = value
    return max_value, min_value     # 두 개의 값을 반환함

list_data = [82, 27, 90, 30, 87, 56]    # 데이터를 여러 개 담는 리스트 자료구조
# getMinAndMax() 함수가 두 개의 값을 반환하므로 두 개의 변수에 이를 담는다
max_v, min_v = getMinAndMax(list_data)

print('리스트의 원소 :') 
print(list_data) 
print('최대값 :', max_v) 
print('최소값 :', min_v)
# Out:
# 리스트의 원소 :
# [82, 27, 90, 30, 87, 56]
# 최대값 : 90
# 최소값 : 27

# %% [markdown]
# ### 6.7 자신을 호출하는 재귀 함수

# %%
def factorial(n):                   # n!의 재귀적 구현
    if n <= 1:                      # 종료 조건이 반드시 필요하다
        return 1
    else:
        return n * factorial(n-1)   # n * (n-1)! 정의에 따른 구현

print('4! = ', factorial(4))        # 인자로 4를 넣어 호출
# Out:
# 4! =  24

# %% [markdown]
# ### LAB 6-6 피보나치 함수 계산하기

# %%
def fibonacci(n):
    if n < 0:                                   # 입력 오류 검사
        print("잘못된 입력입니다.")
    elif n == 1:                                # 재귀호출 중단 조건
        return 0
    elif n == 2:                                # 재귀호출 중단 조건
        return 1
    else:
        return fibonacci(n-1) + fibonacci(n-2)  # 재귀호출

i = int(input("몇 번째 항을 구할까요: "))
print(fibonacci(i))
# Out:
# 21

# %% [markdown]
# ### 6.8 모듈을 이용해서 함수를 재사용하자

# %%
import datetime              # 날짜와 시간을 다루는 모듈
datetime.datetime.now()
# Out:
# datetime.datetime(2020, 9, 18, 5, 1, 25, 329300)

# %%
today = datetime.date.today()
print(today)
# Out:
# 2020-09-18

# %%
today
# Out:
# datetime.date(2020, 9, 18)

# %%
today.year
# Out:
# 2020

# %%
today.month
# Out:
# 9

# %%
today.day
# Out:
# 18

# %% [markdown]
# #### 나만의 모듈을 만들고 불러서 사용해 보자

# %%
# filename: my_func.py
def mf_print(msg, n = 1) :      # msg를 n번 반복하는 함수
   print(msg * n)

# %%
# filename: main.py
import my_func

my_func.mf_print("반복하여 출력 ", 3)  # my_func 모듈의 mf_print() 함수 호출
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[39], line 2
#       1 # filename: main.py
# ----> 2 import my_func
#       4 my_func.mf_print("반복하여 출력 ", 3)  # my_func 모듈의 mf_print() 함수 호출
#
# ModuleNotFoundError: No module named 'my_func'

# %% [markdown]
# ### 6.9 모듈과 별명 만들기

# %%
# filename: main.py
import my_func as mf

mf.mf_print('반복하여 출력 ', 3)  # mf라는 별명을 사용해서 메시지를 반복출력
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[40], line 2
#       1 # filename: main.py
# ----> 2 import my_func as mf
#       4 mf.mf_print('반복하여 출력 ', 3)  # mf라는 별명을 사용해서 메시지를 반복출력
#
# ModuleNotFoundError: No module named 'my_func'

# %%
# filename: main.py
from my_func import mf_print

mf_print('-no module name-', 2)  # mf_print()를 호출할 때 my_func.을 사용안해도 됨
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[41], line 2
#       1 # filename: main.py
# ----> 2 from my_func import mf_print
#       4 mf_print('-no module name-', 2)  # mf_print()를 호출할 때 my_func.을 사용안해도 됨
#
# ModuleNotFoundError: No module named 'my_func'

# %%
# filename: main.py
from my_func import *

mf_print('-no module name-', 2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[42], line 2
#       1 # filename: main.py
# ----> 2 from my_func import *
#       4 mf_print('-no module name-', 2)
#
# ModuleNotFoundError: No module named 'my_func'

# %%
import turtle           # 터틀 그래픽 모듈을 가져온다

t = turtle.Turtle()     # 거북이 객체를 생성함, t라는 변수로 참조함
t.shape("turtle")       # 거북이 객체 t에 내리는 명령 shape()은 메소드라고 함
t.forward(100)          # 거북이 객체 t에 내리는 명령 forward() 역시 메소드라고 함 
s = turtle.Turtle()     # 새로운 거북이 객체를 생성함, s라는 변수로 참조함
s.shape("square") 
s.backward(100) 

turtle.done()           # 이 거북이 그래픽 프로그램이 사용자의 입력을 받아서 실행하는 루프로 진입
