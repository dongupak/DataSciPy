# %% [markdown]
# # 생능출판사 "따라하며 배우는 파이썬과 데이터과학" 코드 1장
# ## chapter 1
# ### 데이터 과학과 파이썬의 세계로

# %% [markdown]
# ### 1.3 프로그래밍을 꼭 알아야 하나?

# %%
from collections import Counter

f = open("d:/mobydick.txt", encoding="utf-8") 
count = Counter(f.read().split())
print("단어 출현 횟수 :", count)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 from collections import Counter
# ----> 3 f = open("d:/mobydick.txt", encoding="utf-8")
#       4 count = Counter(f.read().split())
#       5 print("단어 출현 횟수 :", count)
#
# File ~/Library/Python/3.11/lib/python/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'd:/mobydick.txt'

# %% [markdown]
# ### 1.4 파이썬 개발 도구 설치하기

# %% [markdown]
# #### 파이썬 인터프리터를 사용해보기

# %%
print('Hello Python!!')
# Out:
# Hello Python!!

# %%
5 + 6
# Out:
# 11

# %%
반지름 = 4
면적 = 3.14 * 반지름 * 반지름
print(면적)
# Out:
# 50.24

# %% [markdown]
# ### 1.5 파이썬 개발도구에서 'Hello World'를 출력해보자

# %% [markdown]
# #### 주석으로 이해하기 쉬운 코드를 만들기

# %%
# 다음 코드는 반지름을 이용하여 원의 면적을 출력하는 코드이다
반지름 = 4                     # 반지름의 값을 저장합니다.
면적 = 3.14 * 반지름 * 반지름     # 반지름의 값을 이용하여 원의 면적을 구합니다.
print(면적)                    # 면적을 화면에 출력합니다.
# Out:
# 50.24

# %%
# 여러 줄의 주석을 사용할 때
# 해시 표시를 문장의 첫 줄에 넣어서 주석을 사용할 수 있다

# %%
'''
작은따옴표를 이용하여 여러 줄 주석을 만드는 방법이다
이 방식으로 주석을 만들면
여러 줄에 걸친 주석을 남길 수 있다
'''
# Out:
# '\n작은따옴표를 이용하여 여러 줄 주석을 만드는 방법이다\n이 방식으로 주석을 만들면\n여러 줄에 걸친 주석을 남길 수 있다\n'

# %%
"""
혹은 이와 같이 큰따옴표를 이용할 수도 있다
큰따옴표를 사용해도 작은따옴표를 사용하는 것과 동일하다
"""
# Out:
# '\n혹은 이와 같이 큰따옴표를 이용할 수도 있다\n큰따옴표를 사용해도 작은따옴표를 사용하는 것과 동일하다\n'

# %% [markdown]
# ### 1.6 무작정 계산부터 해보자

# %%
 2 + 3
# Out:
# 5

# %%
print(2 + 3)
# Out:
# 5

# %%
print(2 - 3)
# Out:
# -1

# %%
print(2 * 3)
# Out:
# 6

# %%
print(2 / 3)
# Out:
# 0.6666666666666666

# %%
print(2345 * 9876 - 5678)
# Out:
# 23153542

# %%
print(123456789123456789 * 123456789123456789)
# Out:
# 15241578780673678515622620750190521

# %% [markdown]
# #### print() 함수로 원하는 메시지 출력해 보기

# %%
'Hello'   #문자열 'Hello'
# Out:
# 'Hello'

# %%
"Hello"    #문자열 "Hello"는 'Hello'와 동일하다
# Out:
# 'Hello'

# %%
print('Hello')     # print() 함수안에 문자열이 있을 경우 따옴표는 나타나지 않음
# Out:
# Hello

# %%
print("즐거운 " + "파이썬 익히기")  # 두 텍스트 데이터를 연결하여 출력함
# Out:
# 즐거운 파이썬 익히기

# %%
print('반가워요 ' * 10)  # '반가워요'를 10회 반복 출력함
# Out:
# 반가워요 반가워요 반가워요 반가워요 반가워요 반가워요 반가워요 반가워요 반가워요 반가워요

# %%
print("100" + "200")  # 문자열 '100', '200'을 연결한다
# Out:
# 100200

# %%
print(100 + 200)  # 숫자 두 개의 합을 구한다
# Out:
# 300

# %% [markdown]
# ### 1.8 터틀 그래픽으로 눈에 보이는 결과를 만들어 보자

# %%
import turtle            # turtle 모듈을 사용하기 위해 준비한다
t = turtle.Turtle()      # turtle 모듈에 있는 Turtle 클래스 객체를 t로 생성한다
t.shape('turtle')        # Turtle 클래스 객체인 t의 모양을 거북이 모양으로 설정한다
# Out:
# 2024-01-31 14:43:44.541 Python[74427:7312644] WARNING: Secure coding is not enabled for restorable state! Enable secure coding by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState: and returning YES.

# %%
t.forward(100)    # 거북이를 전진(forward)시키는 명령어로 100픽셀 만큼 이동

# %%
t.left(90)       # 거북이를 왼쪽으로(left) 90도 회전시키는 명령어 
t.forward(50)

# %% [markdown]
# ### 1.9 파이썬이 정말로 편리한 이유 : 모듈 설치하기

# %%
C:\> pip install package-name

# %%
C:\> pip install numpy matplotlib pandas scikit-learn seaborn wikipedia wordcloud

# %% [markdown]
#  #### 오류가 발생할 수 있다

# %%
PRINT("Hello World")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 PRINT("Hello World")
#
# NameError: name 'PRINT' is not defined

# %%
print(Good Bye)
# Out:
#   Cell In[32], line 1
#     print(Good Bye)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# ### LAB 1-1 자주 사용하게 될 print() 함수를 연습해 보자

# %%
print("안녕하세요? 여러분")
# Out:
# 안녕하세요? 여러분

# %%
print("저는 파이썬을 무척 좋아합니다.")
# Out:
# 저는 파이썬을 무척 좋아합니다.

# %%
print("9*8은", 9*8, "입니다.")
# Out:
# 9*8은 72 입니다.

# %%
print("안녕히 계세요.")
# Out:
# 안녕히 계세요.

# %% [markdown]
# ### LAB 1-2 터틀 그래픽으로 삼각형을 그려 보자

# %%
import turtle 
t=turtle.Turtle() 
t.shape("turtle") 
t.forward(100) 
t.left(120) 
t.forward(100) 
t.left(120) 
t.forward(100)
# Out:
# 2024-02-01 14:11:44.893 Python[3935:77548] WARNING: Secure coding is not enabled for restorable state! Enable secure coding by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState: and returning YES.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
